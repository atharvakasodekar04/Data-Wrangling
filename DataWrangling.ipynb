# %%
#To import pandas library
import pandas as pd

# %%
# To access dataset into dataframe
datav1= pd.read_csv('vehicles.csv')

# %%
#Display column names
datav1.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %%
#copy first 50 rows into new dataframe datav2
datav2= datav1.head(5)

# %%
# display or access contents of more than one column
datav2[['id','url','region']]
# Out:
#             id                                                url  \
# 0   7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1   7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2   7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3   7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4   7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# 5   7222379453  https://hudsonvalley.craigslist.org/cto/d/west...
# 6   7221952215  https://hudsonvalley.craigslist.org/cto/d/west...
# 7   7220195662  https://hudsonvalley.craigslist.org/cto/d/poug...
# 8   7209064557  https://medford.craigslist.org/cto/d/grants-pa...
# 9   7219485069  https://erie.craigslist.org/cto/d/erie-2012-su...
# 10  7218893038  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 11  7218325704  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 12  7217788283  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# ...

# %%
# Display data of dataframe
datav2
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# ...

# %%
## Multiple row and column selections using iloc and DataFrame
#The iloc indexer syntax is data.iloc[<row selection>, <column selection>]
datav2.iloc[0:5] # first five rows of dataframe
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# ...

# %%
datav2.iloc[:, 0:1] # first two columns of data frame with all rows
# Out:
#            id
# 0  7222695916
# 1  7218891961
# 2  7221797935
# 3  7222270760
# 4  7210384030

# %%
datav1.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
# Out:
#             id  year manufacturer
# 0   7222695916   NaN          NaN
# 3   7222270760   NaN          NaN
# 6   7221952215   NaN          NaN
# 24  7213843538   NaN          NaN

# %%
datav2.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame
# Out:
#    year manufacturer model
# 0   NaN          NaN   NaN
# 1   NaN          NaN   NaN
# 2   NaN          NaN   NaN
# 3   NaN          NaN   NaN
# 4   NaN          NaN   NaN

# %%
#Display single column or to access single column
datav2['region']
# Out:
# 0                  prescott
# 1              fayetteville
# 2              florida keys
# 3    worcester / central MA
# 4                greensboro
# Name: region, dtype: object

# %%
#display single row using slicing
datav2[0:2]
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
#
#          region                       region_url  price  year manufacturer  \
# 0      prescott  https://prescott.craigslist.org   6000   NaN          NaN
# 1  fayetteville     https://fayar.craigslist.org  11900   NaN          NaN
#
#   model condition cylinders  ... size  type paint_color image_url description  \
# 0   NaN       NaN       NaN  ...  NaN   NaN         NaN       NaN         NaN
# 1   NaN       NaN       NaN  ...  NaN   NaN         NaN       NaN         NaN
#
#   county state lat long posting_date
# 0    NaN    az NaN  NaN          NaN
# 1    NaN    ar NaN  NaN          NaN
#
# [2 rows x 26 columns]

# %%
# another way to access contents of more than one column
list1 = ['id','url','region']
datav2[list1]
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region
# 0                prescott
# 1            fayetteville
# 2            florida keys
# 3  worcester / central MA
# 4              greensboro

# %%
# create new dataframe of 50 rows and three columns
datav3=datav2.iloc[0:50,0:3]

# %%
# enables us to select a particular cell of the dataset
datav2.iloc[0:8,0:4]
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url
# 0                prescott    https://prescott.craigslist.org
# 1            fayetteville       https://fayar.craigslist.org
# 2            florida keys        https://keys.craigslist.org
# 3  worcester / central MA   https://worcester.craigslist.org
# 4              greensboro  https://greensboro.craigslist.org

# %%
datav2 = datav2.drop('url', axis=1)   #drop particular column

# %%
datav2
# Out:
#             id                  region                           region_url  \
# 0   7222695916                prescott      https://prescott.craigslist.org
# 1   7218891961            fayetteville         https://fayar.craigslist.org
# 2   7221797935            florida keys          https://keys.craigslist.org
# 3   7222270760  worcester / central MA     https://worcester.craigslist.org
# 4   7210384030              greensboro    https://greensboro.craigslist.org
# 5   7222379453           hudson valley  https://hudsonvalley.craigslist.org
# 6   7221952215           hudson valley  https://hudsonvalley.craigslist.org
# 7   7220195662           hudson valley  https://hudsonvalley.craigslist.org
# 8   7209064557         medford-ashland       https://medford.craigslist.org
# 9   7219485069                    erie          https://erie.craigslist.org
# 10  7218893038                 el paso        https://elpaso.craigslist.org
# ...

# %%
#datav2['age']= 2022-datav2['year'] #creating new column in dataframe

# %%
#datav2['age']

# %%
#datav2['age'].dtype  # knowing datatype of variable

# %%
#datav2['region']

# %%
#datav2['region'].unique  #displays unique entries of the particulat column

# %%
#datav2[datav2.age<5]  #displays data with condition

# %%
#datav4 = datav2[(datav2.age<5)&(datav2.price>50000)] #store data into new dataframe based on condition or/and

# %%
datav2['price_mile'] = datav2['price']/datav2['odometer']  #new feature creation with calculations on columns

# %%
datav2['price_mile']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27     0.579908
# 28     0.317146
# 29     2.066284
# 30     0.753575
# 31     0.117188
# 32     0.407447
# 33     1.172582
# 34     0.813953
# 35     1.733326
# 36     1.276251
# 37     0.023438
# 38     1.098166
# 39     0.602933
# 40     0.886949
# 41     1.572030
# 42     3.914880
# 43     0.607953
# 44    16.897492
# 45     0.749759
# 46     0.000000
# 47     1.658516
# 48     1.013720
# 49     1.602935
# Name: price_mile, dtype: float64

# %%
# function or defination to double the price of particular column
def pricedouble(x):
    return x*2
datav2['pricedouble'] = datav2['price'].apply(pricedouble)

# %%
datav2[['price','pricedouble']]
# Out:
#     price  pricedouble
# 0    6000        12000
# 1   11900        23800
# 2   21000        42000
# 3    1500         3000
# 4    4900         9800
# 5    1600         3200
# 6    1000         2000
# 7   15995        31990
# 8    5000        10000
# 9    3000         6000
# 10      0            0
# 11      0            0
# 12      0            0
# 13      0            0
# 14      0            0
# 15  13995        27990
# 16  24999        49998
# 17  21850        43700
# 18  26850        53700
# 19  11999        23998
# 20  24999        49998
# 21  21850        43700
# 22  26850        53700
# 23  11999        23998
# 24  24999        49998
# 25  21850        43700
# 26    500         1000
# 27  33590        67180
# 28  22590        45180
# 29  39590        79180
# 30  30990        61980
# 31  15000        30000
# 32  27990        55980
# 33  34590        69180
# 34  35000        70000
# 35  29990        59980
# 36  38590        77180
# 37   4500         9000
# 38  32990        65980
# ...

# %%
datav2['pr'] = datav2.price.apply(lambda x:x*4)   #function can be written and applyed using apply function and lambda is used for single line function

# %%
datav2[['price','pr']]
# Out:
#     price      pr
# 0    6000   24000
# 1   11900   47600
# 2   21000   84000
# 3    1500    6000
# 4    4900   19600
# 5    1600    6400
# 6    1000    4000
# 7   15995   63980
# 8    5000   20000
# 9    3000   12000
# 10      0       0
# 11      0       0
# 12      0       0
# 13      0       0
# 14      0       0
# 15  13995   55980
# 16  24999   99996
# 17  21850   87400
# 18  26850  107400
# 19  11999   47996
# 20  24999   99996
# 21  21850   87400
# 22  26850  107400
# 23  11999   47996
# 24  24999   99996
# 25  21850   87400
# 26    500    2000
# 27  33590  134360
# 28  22590   90360
# 29  39590  158360
# 30  30990  123960
# 31  15000   60000
# 32  27990  111960
# 33  34590  138360
# 34  35000  140000
# 35  29990  119960
# 36  38590  154360
# 37   4500   18000
# 38  32990  131960
# 39  24590   98360
# 40  30990  123960
# 41  27990  111960
# 42  37990  151960
# 43  33590  134360
# 44  30990  123960
# 45  27990  111960
# 46      0       0
# 47  34590  138360
# 48  30590  122360
# ...

# %%
mylist = ["a", "b", "a", "c", "c"]
mylist = list(dict.fromkeys(mylist))
print(mylist)
# Out:
# ['a', 'b', 'c']

# %%
datav2['region']
# Out:
# 0                   prescott
# 1               fayetteville
# 2               florida keys
# 3     worcester / central MA
# 4                 greensboro
# 5              hudson valley
# 6              hudson valley
# 7              hudson valley
# 8            medford-ashland
# 9                       erie
# 10                   el paso
# 11                   el paso
# 12                   el paso
# 13                   el paso
# 14                   el paso
# 15                bellingham
# 16                bellingham
# 17                bellingham
# 18                bellingham
# 19                bellingham
# 20                bellingham
# 21                bellingham
# 22                bellingham
# 23                bellingham
# 24     skagit / island / SJI
# 25     skagit / island / SJI
# 26                 la crosse
# 27                    auburn
# 28                    auburn
# 29                    auburn
# 30                    auburn
# 31                    auburn
# ...

# %%
#REMOVING DUPLICATES

# %%
datav2['region']
datav5= list(dict.fromkeys(datav2['region']))
print(datav5)
# Out:
# ['prescott', 'fayetteville', 'florida keys', 'worcester / central MA', 'greensboro', 'hudson valley', 'medford-ashland', 'erie', 'el paso', 'bellingham', 'skagit / island / SJI', 'la crosse', 'auburn']

# %%
test_list = [1, 5, 3, 6, 3, 5, 6, 1]
print ("The original list is : " +  str(test_list))
  
# using set()
# to remove duplicated 
# from list 
test_list = list(set(test_list))
  
# printing list after removal 
# distorted ordering
print ("The list after removing duplicates : " + str(test_list))
# Out:
# The original list is : [1, 5, 3, 6, 3, 5, 6, 1]
# The list after removing duplicates : [1, 3, 5, 6]

# %%
datav2['region']
print ("The original list is : " +  str(datav2['region']))
  
# using set()
# to remove duplicated 
# from list 
test_list = list(set(datav2['region']))
  
# printing list after removal 
# distorted ordering
print ("The list after removing duplicates : " + str(test_list))
# Out:
# The original list is : 0                   prescott
# 1               fayetteville
# 2               florida keys
# 3     worcester / central MA
# 4                 greensboro
# 5              hudson valley
# 6              hudson valley
# 7              hudson valley
# 8            medford-ashland
# 9                       erie
# 10                   el paso
# 11                   el paso
# 12                   el paso
# 13                   el paso
# 14                   el paso
# 15                bellingham
# 16                bellingham
# 17                bellingham
# 18                bellingham
# 19                bellingham
# 20                bellingham
# 21                bellingham
# 22                bellingham
# 23                bellingham
# 24     skagit / island / SJI
# 25     skagit / island / SJI
# 26                 la crosse
# 27                    auburn
# 28                    auburn
# 29                    auburn
# 30                    auburn
# ...

# %%
#convert the categorical variable values into numerical (label encoding)
datav2['size']=datav2['size'].map({'full-size':0,'mid-size':1,'compact':2,'sub-compact':3})

# %%
datav2['size'].value_counts()   #counts values of each categories
# Out:
# 0.0    2
# Name: size, dtype: int64

# %%
datav2.shape   #display tuple of size in (rows, columns) or no of element in each dimension
# Out:
# (50, 26)

# %%
datav2.describe()#is used to view some basic statistical details like percentile, mean, std etc.
# Out:
#                  id         price         year       odometer  size  county  \
# count  5.000000e+01     50.000000    23.000000      23.000000   2.0     0.0
# mean   7.262865e+09  19246.900000  2014.608696   47699.521739   0.0     NaN
# std    4.952944e+07  13268.776049     5.702783   42850.728957   0.0     NaN
# min    7.208550e+09      0.000000  1992.000000    1834.000000   0.0     NaN
# 25%    7.218540e+09   4925.000000  2013.500000   20718.500000   0.0     NaN
# 50%    7.222724e+09  22220.000000  2016.000000   34940.000000   0.0     NaN
# 75%    7.315767e+09  30890.000000  2017.500000   56587.000000   0.0     NaN
# max    7.316815e+09  39590.000000  2020.000000  192000.000000   0.0     NaN
#
#              lat       long        age  price_mile   pricedouble  \
# count  23.000000  23.000000  23.000000   23.000000     50.000000
# mean   32.591139 -85.475190   7.391304    1.733323  38493.800000
# std     0.015041   0.024084   5.702783    3.411094  26537.552099
# ...

# %%
datav2.isnull().sum() #display sum of missing values in dataframe
# Out:
# id               0
# region           0
# region_url       0
# price            0
# year            27
# manufacturer    27
# model           27
# condition       27
# cylinders       34
# fuel            27
# odometer        27
# title_status    27
# transmission    27
# VIN             31
# drive           38
# size            48
# type            28
# paint_color     29
# image_url       27
# description     27
# county          50
# state            0
# lat             27
# long            27
# posting_date    27
# age             27
# price_mile      27
# pricedouble      0
# pr               0
# dtype: int64
